# %%
import pymongo
import pandas as pd
koneksi4 = pymongo.MongoClient\
        ("mongodb://ferina:nw9f20d@10.25.4.100:27017/alfagift_product")
mydb = koneksi4["alfagift_product"]
mycol = mydb["alfagift_mcs_prices"]

# %%
for i in range(0,2,1):
    print(i)
# Out:
# 0
# 1

# %%
cp = pd.read_excel('../20210421_TagI_Competitiveness.xlsx', sheet_name=1)

# %%
cp
# Out:
#        PLU                           PRODUK  \
# 0   426116     TROP'S SALTY SOY SAUCE 200ML
# 1   426117           TROP'S SOY SAUCE 200ML
# 2   426118    TROP'S SUGAR FREE HONEY 350ML
# 3   150074            TROP'S CORN OIL 946ML
# 4   426120     TROP'S EXT VRG OLV OIL 500ML
# ..     ...                              ...
# 79  426604      Lotus Biscoff Biscuit 156 g
# 80  425947        JOHNSONS B CTN BATH 500ML
# 81  340065  JOHNSON'S B.BATH MILK+RICE500ML
# 82  426449     XTRAGIN LEMON JAHE BOX 5X18G
# 83  426450    XTRAGIN KUNYIT ASAM BOX 5X23G
#
#                                                   url
# 0   https://www.klikindomaret.com/product/salty-so...
# 1    https://www.klikindomaret.com/product/kecap-diet
# 2   https://www.klikindomaret.com/product/sugar-fr...
# 3    https://www.klikindomaret.com/product/corn-oil-2
# 4   https://www.klikindomaret.com/product/extra-vi...
# ..                                                ...
# ...

# %%
mcs_prices = pd.DataFrame(mycol.find({"tag_prod": "I"}))

# %%
mcs_prices
# Out:
#                                      _id kode_dc     plu  qty0  qty1  qty2  \
# 0     {'kode_dc': 'KZ01', 'plu': 850630}    KZ01  850630   0.0   0.0   1.0
# 1     {'kode_dc': 'KZ01', 'plu': 321705}    KZ01  321705   0.0   0.0   1.0
# 2     {'kode_dc': 'KZ01', 'plu': 416798}    KZ01  416798   0.0   0.0   1.0
# 3     {'kode_dc': 'KZ01', 'plu': 416799}    KZ01  416799   0.0   0.0   1.0
# 4     {'kode_dc': 'KZ01', 'plu': 416800}    KZ01  416800   0.0   0.0   1.0
# ...                                  ...     ...     ...   ...   ...   ...
# 4132  {'kode_dc': 'KZ01', 'plu': 426449}    KZ01  426449   0.0   0.0   1.0
# 4133  {'kode_dc': 'KZ01', 'plu': 426450}    KZ01  426450   NaN   NaN   NaN
# 4134  {'kode_dc': '1MZ1', 'plu': 426448}    1MZ1  426448   0.0   0.0   1.0
# 4135  {'kode_dc': '1MZ1', 'plu': 426449}    1MZ1  426449   0.0   0.0   1.0
# 4136  {'kode_dc': '1MZ1', 'plu': 426450}    1MZ1  426450   NaN   NaN   NaN
#
# ...

# %%
import pymysql
con_mysql = pymysql.connect(host='35.247.191.177',
                             user='user_bc',
                             password='bcgl12021',
                             db='report')

# %%
q = 'select * from alfagift_tag_i'

# %%
alfagift_tag = pd.read_sql(q, con_mysql)

# %%
alfagift_tag
# Out:
#      ati_sku                                   ati_product_name  \
# 0      42621    MamyPoko Pants Royal Soft - S 70 - Popok Celana
# 1     426220  PONDAN BROWNIES KUKUS KETAN HITAM LAPIS PANDAN...
# 2     404232                              PEWARNA COKLAT (30ml)
# 3     426235              Jay's Nutmeg Ground (Pala Bubuk) 65gr
# 4     819654  Pampers Premium Care Celana XL 54 pcs – Extra ...
# ..       ...                                                ...
# 165   426122  Tropicana Slim Sambal Terasi 200 gram - Bantu ...
# 166   426103               Mujigae Oden Korean Fish Cake 120 gr
# 167   417243            Zwitsal Baby Fabric Softener 425 ml NEW
# 168   838542            Appeton Weight Gain Adult Vanilla 450Gr
# 169    42627            Saniter All Surface Bottle Spray 450 ml
#
#      ati_product_price           ati_product_seller  \
# 0               152900                  unicharm.id
# 1                21800                   pondanfood
# ...
